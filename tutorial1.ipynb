# %% [markdown]
# ## PYTHON TUTORIAL##
# This is my first tutorial as a data analyst

# %%
x=[3,5,7,9,11]
y=[1,2,3,3,4]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[3,5,7,9,11]
y=[1,2,3,3,4]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
